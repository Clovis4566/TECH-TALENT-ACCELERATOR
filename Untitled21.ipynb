# %% [markdown]
# <a href="https://colab.research.google.com/github/Clovis4566/TECH-TALENT-ACCELERATOR/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
#creat un simple tableau
mon_tableau=np.array([1,2,3,4,5,6,7])
print ( "mon tableau est :",mon_tableau)
# Out:
# mon tableau est : [1 2 3 4 5 6 7]

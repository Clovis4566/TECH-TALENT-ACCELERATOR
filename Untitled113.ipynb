# %% [markdown]
# <a href="https://colab.research.google.com/github/Clovis4566/TECH-TALENT-ACCELERATOR/blob/main/Untitled113.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Set up your environment
# Installation des bibliothèques nécessaires pour l'orchestration, les modèles et la recherche vectorielle.

# %%
# !pip install -qU langchain langchain-community langchain-huggingface langchain-text-splitters torch transformers sentence-transformers datasets faiss-cpu
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.6/139.6 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.6/526.6 MB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.2/366.2 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.1/170.1 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.0/206.0 MB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.7/197.7 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 107.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 MB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 84.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.1/214.1 MB 6.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# # 2. Load the dataset
# Nous utilisons le dataset `databricks-dolly-15k` et extrayons la colonne `context`.

# %%
from langchain_community.document_loaders import HuggingFaceDatasetLoader

dataset_name = "databricks/databricks-dolly-15k"
page_content_column = "context"

loader = HuggingFaceDatasetLoader(dataset_name, page_content_column)
data = loader.load()
print(f"Loaded {len(data)} documents.")
print("Sample content:", data[0].page_content[:200])
# Out:
# /tmp/ipykernel_865/2278880172.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import HuggingFaceDatasetLoader
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/8.20k [00:00<?, ?B/s]
# databricks-dolly-15k.jsonl: reconstructing file:   0%|          |  0.00B / 13.1MB
# databricks-dolly-15k.jsonl: downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/15011 [00:00<?, ? examples/s]
# Loaded 15011 documents.
# ...

# %% [markdown]
# # 3. Split the documents
# Le texte est divisé en morceaux de 1000 caractères avec un chevauchement pour garder le contexte.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=150)
docs = text_splitter.split_documents(data)
print(f"Nombre de segments créés: {len(docs)}")
# Out:
# Nombre de segments créés: 18502

# %% [markdown]
# # 4. Embed the text
# On transforme les mots en vecteurs mathématiques compréhensibles par la machine.

# %%
from langchain_huggingface import HuggingFaceEmbeddings

modelPath = "sentence-transformers/all-MiniLM-l6-v2"
model_kwargs = {'device':'cpu'}
encode_kwargs = {'normalize_embeddings': False}

embeddings = HuggingFaceEmbeddings(
    model_name=modelPath,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %% [markdown]
# # 5. Create a vector store
# On utilise FAISS pour indexer nos vecteurs afin de pouvoir chercher rapidement.

# %%
from langchain_community.vectorstores import FAISS

# Initialisation du vector store avec les documents découpés
# On utilise une partie du dataset pour la démo
db = FAISS.from_documents(docs[:500], embeddings)
print("Vector store created successfully with FAISS.")
# Out:
# Vector store created successfully with FAISS.

# %% [markdown]
# # 6. Prepare the LLM model
# Configuration du pipeline de Question-Answering avec TinyBERT.

# %%
from transformers import AutoTokenizer, pipeline
from langchain_community.llms import HuggingFacePipeline

model_name = "Intel/dynamic_tinybert"
tokenizer = AutoTokenizer.from_pretrained(model_name, padding=True, truncation=True, max_length=512)

# Create the pipeline
qa_pipeline = pipeline(
    "question-answering",
    model=model_name,
    tokenizer=tokenizer
)

llm = HuggingFacePipeline(pipeline=qa_pipeline)
# Out:
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/351 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_865/2467242587.py in <cell line: 0>()
#       6
#       7 # Create the pipeline
# ----> 8 qa_pipeline = pipeline(
#       9     "question-answering",
#      10     model=model_name,
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     972             )
# ...

# %% [markdown]
# # 7. Build the Retrieval QA Chain
# On connecte le récupérateur (retriever) au modèle de langue.

# %%
import langchain
from langchain.chains import RetrievalQA

# Configuration du retriever à partir de la base FAISS
retriever = db.as_retriever(search_kwargs={"k": 4})

# Construction de la chaîne de question-réponse
try:
    qa = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="refine",
        retriever=retriever,
        return_source_documents=False
    )
    print("La chaîne RetrievalQA est prête.")
except Exception as e:
    print(f"Erreur lors de la création de la chaîne : {e}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_865/2363393613.py in <cell line: 0>()
# ----> 1 from langchain.chains import RetrievalQA
#       2
#       3 # Configuration du retriever à partir de la base FAISS
#       4 retriever = db.as_retriever(search_kwargs={"k": 4})
#       5
#
# ModuleNotFoundError: No module named 'langchain.chains'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # 8. Test your RAG system
# Test final avec une question.

# %%
question = "What is cheesemaking?"
# Use invoke instead of run in recent LangChain versions
try:
    result = qa.invoke({"query": question})
    print("Question:", question)
    print("Answer:", result["result"])
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: name 'qa' is not defined

# %% [markdown]
# <a href="https://colab.research.google.com/github/Clovis4566/TECH-TALENT-ACCELERATOR/blob/main/Untitled119.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
get_ipython().system('%pip install -qU   "langchain>=0.3"   "langgraph>=0.2"   "langchain-google-genai>=2.0"   "google-genai>=1.0"   "nest_asyncio"')
# Out:
# /bin/bash: line 1: fg: no job control

# %%
# %pip install -U langchain-mcp-adapters==0.2.1 -v # Use %pip magic command for installation
get_ipython().system('pip show langchain-mcp-adapters') # Verify installation
# Out:
# Using pip 24.1.2 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)
# ...
#   Obtaining dependency information for langchain-mcp-adapters==0.2.1 from https://files.pythonhosted.org/packages/03/81/b2479eb26861ab36be851026d004b2d391d789b7856e44c272b12828ece0/langchain_mcp_adapters-0.2.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for mcp>=1.9.2 from https://files.pythonhosted.org/packages/e2/5e/d118fce19f87a2e7d8101c35c8ae0ec289098a4df0ff244cec23e415aca0/mcp-1.28.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for httpx-sse>=0.4 from https://files.pythonhosted.org/packages/d2/fd/6668e5aec43ab844de6fc74927e155a3b37bf40d7c3790e49fc0406b6578/httpx_sse-0.4.3-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for pydantic-settings>=2.5.2 from https://files.pythonhosted.org/packages/77/c1/6e422f34e569cf8e18df68d1939c81c099d2b61e4f7d9621c8a77560799c/pydantic_settings-2.14.2-py3-none-any.whl.metadata
# ...

# %%
get_ipython().system('node --version')
get_ipython().system('npx --version')
# Out:
# v20.19.0
# 10.8.2

# %%
# To use Gemini models, you need to set the GOOGLE_API_KEY environment variable.
# Please replace 'YOUR_API_KEY' with your actual Google API Key.
import os
os.environ['GOOGLE_API_KEY'] = 'YOUR_API_KEY'

# You can verify it's set (optional)
# print(os.environ.get('GOOGLE_API_KEY'))

# %%
import asyncio
from langchain_mcp_adapters.client import MultiServerMCPClient

WORKDIR = '/content'

mcp_connections = {
    "filesystem": {
        "transport": "stdio",
        "command": "npx",
        "args": ["-y", "@modelcontextprotocol/server-filesystem", WORKDIR],
    },
    "git": {
        "transport": "stdio",
        "command": "python",
        "args": ["-m", "mcp_server_git", "--repository", WORKDIR],
    },
}

# Initialize the client (Note: This will not launch the servers yet, just register them)
client = MultiServerMCPClient(mcp_connections, tool_name_prefix=True)

print("MCP Client initialized with registered servers: ", list(mcp_connections.keys()))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1243/994433940.py in <cell line: 0>()
#       1 import asyncio
# ----> 2 from langchain_mcp_adapters.client import MultiServerMCPClient
#       3
#       4 WORKDIR = '/content'
#       5
#
# ModuleNotFoundError: No module named 'langchain_mcp_adapters'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
